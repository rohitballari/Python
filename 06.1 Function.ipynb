# %% [markdown]
# ## Function
#
# There are 2 Types of Function
# 1. User Defined Function
# 2. Built-in Function

# %% [markdown]
# ### What is Function
# The Function is a block of code which only runs when it is called
# It is Basically an oranized set of rules or instructions, that you wish to perform multiple number of times

# %% [markdown]
# ### Why do we use function
# We use function to Re-usability of code, and Minimizes redundancy (repeating the same code again and again)

# %% [markdown]
# ### Steps involved in a function
#
# 1. You will be defining a function
# 2. You will be calling a function

# %% [raw]
# syntax
#
# def greet():                # greet -- is a function name,   () -- the python should know it's not a variable it's a function,
#     print('Hello')                      # : -- coloun indicates we have multiple statements
#     print('Good Morning')
#
# greet()      # calling a function

# %% [raw]
# ## Types of Arguments in Python
# 1. Formal Arguments
# 2. Actual Arguments
#     1. Position Argument
#     2. Keyword Argument
#     3. Default Argument
#     4.Variable-length Argument
#     5. Keyword variable length argument

# %%
# 1. Position Argument

def name(first_name,last_name):            # (formal argument)
    print(first_name,last_name)
name('Jeevan','Raj')                       # In this position of argument is most important     (actual argument)
# Out:
# Jeevan Raj

# %%
def info(fname,lname,age):
    print(f'full Name = {fname+" "+lname} Age = {age}')

# %%
info(age = 23,fname = 'Vignesh',lname = 'Gowda')
# Out:
# full Name = Vignesh Gowda Age = 23

# %%
# 2. Keyword Argument
def info(name,age):
    print('Name =',name)
    print('Age =',age)
info(age=25,name='Jeevan')
# Out:
# Name = Jeevan
# Age = 25

# %%
# 3. Default Argument
def info(name,age=18):
    print('Name =',name)
    print('Age =',age)

# %%
# 4. Variable Length Argument
def add(*a):
    b=0
    for i in a:
        b+=i
    print(b)

add(12,4,4,15)
# Out:
# 35

# %%
add(5,25)
# Out:
# 30

# %% [markdown]
# #### In Tupple we can't use the keyword so we use **a (where it convert tupple to dictionary), If we use *a (where it will be in tupple)

# %%
def info(*data):
    print(data)

info(Name='Jeevan',Age=25)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 def info(*data):
#       2     print(data)
# ----> 4 info(Name='Jeevan',Age=25)
#
# TypeError: info() got an unexpected keyword argument 'Name'

# %%
# 5. Keyworded variable length argument
def info(**data):
    print(data)

info(Name='Jeevan Raj',Age = 25,Location ='Bangalore')
# Out:
# {'Name': 'Jeevan Raj', 'Age': 25, 'Location': 'Bangalore'}

# %%
def info(**data):
    for i,j in data.items():
        print(i,'=',j)

info(Name = 'Jeevan Raj',Age = 25,Location ='Bangalore')
# Out:
# Name = Jeevan Raj
# Age = 25
# Location = Bangalore

# %% [markdown]
# ### What is the difference between print() and return in Python

# %% [markdown]
# when ever you want to just print the values you can use print function,
# And when ever you want to return some value and store it in a variable and later on if you want to use that variable you can use return keyword

# %% [markdown]
# ![Screenshot_20230115_115940.png](attachment:Screenshot_20230115_115940.png)

# %%
def printsum(num1,num2):
    addition = num1 + num2
    print(addition)
a = printsum(2,3)
# Out:
# 5

# %%
print(a)
# Out:
# None

# %%
def returnsum(num1,num2):
    addition = num1 + num2
    return addition
returnsum(2,3)
# Out:
# 5

# %% [markdown]
# #### You can observe that both does the same work but will see if we are going save the values in variable what happens

# %%
x = printsum(3,5)
# Out:
# 8

# %%
print(x)          # we are used print statement so it just prints it does not returns the value
# Out:
# None

# %%
y = returnsum(3,5)

# %%
print(y)
# Out:
# 8
